# %% [markdown]
# # Data analysis using ML and DL models

# %% [markdown]
# ## Load and preprocess data

# %%
import os
import cv2
import torch
import numpy as np
from torchvision import transforms
import matplotlib.pyplot as plt

# Define the input directory
input_dir = '/home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea'

# Function to load images
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            img = cv2.imread(os.path.join(folder, filename))
            if img is not None:
                images.append(img)
    return images

# Load images
images = load_images_from_folder(input_dir)

# Preprocess images for YOLO
preprocess = transforms.Compose([
    transforms.ToTensor(),
])

# Convert images to numpy arrays
images_np = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in images]

# %% [markdown]
# ## Object detection with YOLOv5

# %%
from ultralytics import YOLO

# Load pre-trained YOLOv5 model
model = YOLO("yolov5su.pt")

# Perform object detection on the batch of images
detections = [model(img) for img in images_np]

# Process detections
for i, detection in enumerate(detections):
    print(f"Image {i+1} detections:")
    if detection[0].probs is not None:
        for idx, box in enumerate(detection[0].boxes.xyxy):
            score = detection[0].probs[idx].item() if detection[0].probs[idx] is not None else 0.0
            class_name = model.names[int(detection[0].classes[idx])]
            print(f"Object {idx+1}: {box.numpy()}, Score: {score}, Class: {class_name}")
    else:
        print("No detections found.")
# Out:
# 0: 128x640 (no detections), 105.7ms
# Speed: 2.4ms preprocess, 105.7ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 544x640 (no detections), 373.4ms
# Speed: 2.5ms preprocess, 373.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 96x640 (no detections), 86.9ms
# Speed: 0.7ms preprocess, 86.9ms inference, 0.4ms postprocess per image at shape (1, 3, 96, 640)
#
# 0: 128x640 (no detections), 94.2ms
# Speed: 0.7ms preprocess, 94.2ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 640)
# 0: 544x640 3 persons, 347.2ms
# Speed: 2.6ms preprocess, 347.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x544 1 person, 342.1ms
# Speed: 2.4ms preprocess, 342.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 544x640 (no detections), 323.1ms
# Speed: 2.6ms preprocess, 323.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 96x640 (no detections), 78.3ms
# Speed: 0.6ms preprocess, 78.3ms inference, 0.4ms postprocess per image at shape (1, 3, 96, 640)
#
# 0: 544x640 3 persons, 343.7ms
# Speed: 2.6ms preprocess, 343.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 317.8ms
# Speed: 2.6ms preprocess, 317.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 128x640 (no detections), 93.5ms
# Speed: 0.7ms preprocess, 93.5ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 544x640 2 persons, 1 tie, 339.0ms
# Speed: 2.5ms preprocess, 339.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 32x640 (no detections), 41.8ms
# Speed: 0.3ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 32, 640)
#
# 0: 544x640 (no detections), 349.8ms
# Speed: 2.6ms preprocess, 349.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 224x640 (no detections), 154.6ms
# Speed: 1.0ms preprocess, 154.6ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 544x640 1 person, 341.3ms
# Speed: 2.6ms preprocess, 341.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 128x640 (no detections), 93.2ms
# Speed: 0.6ms preprocess, 93.2ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 96x640 (no detections), 73.4ms
# Speed: 0.6ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 96, 640)
#
# 0: 544x640 (no detections), 337.0ms
# Speed: 2.6ms preprocess, 337.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x576 15 kites, 363.0ms
# Speed: 3.5ms preprocess, 363.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 192x640 (no detections), 127.7ms
# Speed: 1.0ms preprocess, 127.7ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 544x640 (no detections), 368.2ms
# Speed: 2.5ms preprocess, 368.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
# Image 1 detections:
# No detections found.
# Image 2 detections:
# No detections found.
# Image 3 detections:
# No detections found.
# Image 4 detections:
# No detections found.
# Image 5 detections:
# No detections found.
# Image 6 detections:
# No detections found.
# Image 7 detections:
# No detections found.
# Image 8 detections:
# No detections found.
# Image 9 detections:
# No detections found.
# Image 10 detections:
# No detections found.
# Image 11 detections:
# No detections found.
# Image 12 detections:
# No detections found.
# Image 13 detections:
# No detections found.
# Image 14 detections:
# No detections found.
# Image 15 detections:
# No detections found.
# Image 16 detections:
# No detections found.
# Image 17 detections:
# No detections found.
# Image 18 detections:
# No detections found.
# Image 19 detections:
# No detections found.
# Image 20 detections:
# No detections found.
# Image 21 detections:
# No detections found.
# Image 22 detections:
# No detections found.

# %% [markdown]
# ## Image segmentation using the pre-trained DeepLabV3 model

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from torchvision import models, transforms

# Define paths and constants
input_dir = '/home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea'

output_dir = '../data/segmentation_results'
os.makedirs(output_dir, exist_ok=True)

print(f"Input Directory: {input_dir}")  # Debugging statement
print(f"Output Directory: {output_dir}")  # Debugging statement

# Transformation for input image
preprocess = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load pre-trained DeepLabV3 model
model = models.segmentation.deeplabv3_resnet101(pretrained=True).eval()

def segment_image(image_path):
    print(f"Processing image: {image_path}")  # Debugging statement
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to read image: {image_path}")  # Debugging statement
        return None, None
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    input_tensor = preprocess(image_rgb).unsqueeze(0)  # Add batch dimension

    with torch.no_grad():
        output = model(input_tensor)['out'][0]
    output_predictions = output.argmax(0).byte().cpu().numpy()

    return image, output_predictions

# Perform segmentation on images in the input directory
for img_name in os.listdir(input_dir):
    if img_name.endswith('.jpg') or img_name.endswith('.png'):
        img_path = os.path.join(input_dir, img_name)
        original_image, segmented_image = segment_image(img_path)
        
        if original_image is not None and segmented_image is not None:
            # Save segmented result
            segmented_image_path = os.path.join(output_dir, f'segmented_{img_name}')
            cv2.imwrite(segmented_image_path, segmented_image * 255)  # Scale mask to 0-255
            
            # Debugging: Print the path of the saved file
            print(f"Segmented image saved at: {segmented_image_path}")
            
            # Visualize results
            plt.figure(figsize=(10, 5))
            plt.subplot(1, 2, 1)
            plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
            plt.title('Original Image')
            plt.axis('off')
            
            plt.subplot(1, 2, 2)
            plt.imshow(segmented_image, cmap='gray')
            plt.title('Segmentation Mask')
            plt.axis('off')
            
            plt.tight_layout()
            plt.show()
        else:
            print(f"Failed to process image: {img_path}")  # Debugging statement
# Out:
# Input Directory: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea
# Output Directory: ../data/segmentation_results
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/EST-cta.png
# Segmented image saved at: ../data/segmentation_results/segmented_EST-cta.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/f1-bg.jpg
# Segmented image saved at: ../data/segmentation_results/segmented_f1-bg.jpg
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/engagement_animation.png
# Segmented image saved at: ../data/segmentation_results/segmented_engagement_animation.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/est-cta.png
# Segmented image saved at: ../data/segmentation_results/segmented_est-cta.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/end-background.jpg
# Segmented image saved at: ../data/segmentation_results/segmented_end-background.jpg
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/landing_2.png
# Segmented image saved at: ../data/segmentation_results/segmented_landing_2.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/SMOKE.png
# Segmented image saved at: ../data/segmentation_results/segmented_SMOKE.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/est-copy.png
# Segmented image saved at: ../data/segmentation_results/segmented_est-copy.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/_preview.png
# Segmented image saved at: ../data/segmentation_results/segmented__preview.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/mpu-click_area.png
# Segmented image saved at: ../data/segmentation_results/segmented_mpu-click_area.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/cta.png
# Segmented image saved at: ../data/segmentation_results/segmented_cta.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/landing_1.png
# Segmented image saved at: ../data/segmentation_results/segmented_landing_1.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/legal.png
# Segmented image saved at: ../data/segmentation_results/segmented_legal.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/vod-cta-rev.png
# Segmented image saved at: ../data/segmentation_results/segmented_vod-cta-rev.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/advertised_item.png
# Segmented image saved at: ../data/segmentation_results/segmented_advertised_item.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/ref.jpg
# Segmented image saved at: ../data/segmentation_results/segmented_ref.jpg
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/VOD-cta.png
# Segmented image saved at: ../data/segmentation_results/segmented_VOD-cta.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/ernd_text.png
# Segmented image saved at: ../data/segmentation_results/segmented_ernd_text.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/mpu-engage_area.png
# Segmented image saved at: ../data/segmentation_results/segmented_mpu-engage_area.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/sparks.png
# Segmented image saved at: ../data/segmentation_results/segmented_sparks.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/engagement_instruction.png
# Segmented image saved at: ../data/segmentation_results/segmented_engagement_instruction.png
# Processing image: /home/tewodros_cheru/Challenge_Data/Assets/3c35998c3f4a279a008ac3ffd8481fea/mpu-clickthrough_area.png
# Segmented image saved at: ../data/segmentation_results/segmented_mpu-clickthrough_area.png
